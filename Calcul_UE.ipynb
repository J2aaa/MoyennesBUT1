# %% [markdown]
# ALGO:
# Definir une fonction calculUE
# Demander les notes de l'utilisateur de chaque matiere
# Faire le calcul de moyenne des UE en utilisant les matieres concerné

# %%
moy_1=0
coe_1=0
som_1=0

for i in range(101,104):
    note=float(input("Donnez-moi la note de la ressource R.{}".format(i)))
    coeff=int(input("Donnez-moi le coefficient de la ressource R.{}".format(i)))
    som_1+=note*coeff
    coe_1+=coeff
for i in range(11,13):
    note=float(input("Donnez-moi la note de la SAE.{}".format(i)))
    coeff=int(input("Donnez-moi le coefficient de la SAE.{}".format(i)))
    som_1+=note*coeff
    coe_1+=coeff 
moy_1=som_1/coe_1
print(moy_1)
# Out:
# Donnez-moi la note de la ressource R.101 10
# Donnez-moi le coefficient de la ressource R.101 3
# Donnez-moi la note de la ressource R.102 10
# Donnez-moi le coefficient de la ressource R.102 4
# Donnez-moi la note de la ressource R.103 10
# Donnez-moi le coefficient de la ressource R.103 5
# Donnez-moi la note de la SAE.11 10
# Donnez-moi le coefficient de la SAE.11 1
# Donnez-moi la note de la SAE.12 10
# Donnez-moi le coefficient de la SAE.12 3
# 10.0

# %%
def calculUE():
        note=int(input("Quel est votre moyenne?"))
        coeff=int(input("Quel est le coeff lier a cette note?"))
        UE1=
calculUE()
# Out:
#   Cell In[13], line 4
#     UE1=
#         ^
# SyntaxError: invalid syntax
